# %%
class employee:
    raise_ = 2
    def __init__(self,name,dep,pay):
        self.name=name
        self.dep=dep
        self.pay=pay
    def new(self):
        print(f"my name  {self.name} from {self.dep}")
    def after(self):
        self.pay = int(self.pay*self.raise_)
dep = employee("indar","technical",10000)
dep = employee("indar","technical",10000)
dep.new()
dep.after()
print(dep.pay)
print(dep.name)
# Out:
# my name  indar from technical
# 80000
# indar

# %%
class employee:
    raise_ = 2
    def __init__(self,name,dep,pay):
        self.name=name
        self.dep=dep
        self.pay=pay
    def new(self):
        print(f"my name  {self.name} from {self.dep}")
    def after(self):
        self.pay = int(self.pay*self.raise_)
class department(employee):
    pass
dep = department("inacdar","technical",40000)
print(help(department))
# print(dep.name)
# print(dep.pay)
# Out:
# Help on class department in module __main__:
#
# class department(employee)
#  |  department(name, dep, pay)
#  |
#  |  Method resolution order:
#  |      department
#  |      employee
#  |      builtins.object
#  |
#  |  Methods inherited from employee:
#  |
#  |  __init__(self, name, dep, pay)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  after(self)
#  |
#  |  new(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from employee:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from employee:
#  |
#  |  raise_ = 2
#
# None

# %%
class employee:
    raise_ = 2
    def __init__(self,name,dep,pay):
        self.name=name
        self.dep=dep
        self.pay=pay
    def new(self):
        print(f"my name  {self.name} from {self.dep}")
    def after(self):
        self.pay = int(self.pay*self.raise_)
class department(employee):
    raise_ = 3
dep1 = department("inacdar","technical",10000)
dep2 = employee("inacdar","technical",10000)
dep1.after()
print(dep1.pay)# take value from department
print(dep2.pay)# take value from employee
# print(dep.name)
# print(dep.pay)
# Out:
# 30000
# 10000

# %%
# CREATING A CLASS 
class employee:
    raise_ = 2
    def __init__(self,name,dep,pay):
    #pecial method that runs automatically when an object is created, and it initializes the object's attributes with initial values.
        self.name=name
        self.dep=dep
        self.pay=pay
    def new(self):
        print(f"my name  {self.name} from {self.dep}")
    def after(self):
        self.pay = int(self.pay*self.raise_)

class department(employee):
    raise_ = 3
    def __init__(self,name, dep, pay,lan):
        super().__init__( name,dep, pay)#super() calls the parent class constructor
        # or we can use employee .__init__(self,first,last,pay)
        self.lan = lan

dep1 = department("indar","technical",10000,'python')
dep2 = employee("inacdar","technical",10000,)
dep1.after()
print(dep1.lan)# take value from department
# any changes i make in sub class it will show in parent class

print(dep2.pay)# take value from employee
# print(dep.name)
# print(dep.pay)
# Out:
# python
# 10000

# %%
# CREATING A CLASS 
class employee:
    raise_ = 2
    def __init__(self,name,dep,pay):
        self.name=name
        self.dep=dep
        self.pay=pay

class department(employee):
    raise_ = 3
    def __init__(self,name, dep, pay,lan):
        super().__init__( name,dep, pay)
        self.lan = lan

class manager(employee):
    def __init__(self, name, dep, pay, employee= None):
        super().__init__(name, dep, pay)
        if employee is None:
            self.employee= []
        else:
            self.employee= employee
    def add_emp(self,emp): 
         

dep1 = department("indar","technical",10000,'python')
dep2 = employee("inacdar","technical",10000,)

# %%
print("hello word")
