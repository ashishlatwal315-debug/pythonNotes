# %%
class student:
    def __init__(self):
        self.name = "indar"
s1 = student()
print(s1.name)
# Out:
# indar

# %%
class student:
    def __init__(self):
        self.__name = "indar"# private variable
s1 = student()
print(s1._student__name)#retreve private variable
# Out:
# indar

# %%
class student:
    def __init__(self):
        self.__name = "indar"# private variable
    def data(self):
        return self.__name
s1 = student()
print(s1.data())
# Out:
# indar
