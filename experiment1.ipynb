# %% [markdown]
# # Experiment 1 (python programming)
#
# Name : Ashish latwal
#
# Course : BCA B2
#
# SAP ID : 590027571
#
#                                                               Submitted to : mr . vibhu gautam

# %%
# 1.Install Python and understand difference between scripting and interactive modes in IDLE

# answer:To install Python, you can follow these steps:
   #1. Go to the official Python website at https://www.python.org/downloads/.
    #2. Click on the "Download Python" button to download the latest version of Python for your operating system.
    #3. Run the downloaded installer and follow the installation instructions. Make sure to check the option to add Python to your system PATH during installation.
    #4. then you are ready to use Python.

# %%
#2.	Write Python programs to print strings in the given manner: 
    # a)   Hello Everyone !!! 
    #  b)   Hello 
           #World 
    #c)   Hello 
             # World 
    #d) ‘ Rohit’ s date of birth is 12\05\1999’


print("Hello Everyone !!!")
print("Hello\nWorld")
print("Hello\n\tWorld")
print("Rohit\'s date of birth is 12\\05\\1999")
# Out:
# Hello Everyone !!!
# Hello
# World
# Hello
# 	World
# Rohit's date of birth is 12\05\1999

# %%
"""3.	Declare a string variable called x and assign it the value “Hello”. 
           Print out the value of x 
"""

x = "Hello"
print(x)
# Out:
# Hello

# %%
#4.	Take different data types and print values using print function

# Integer
age = 25
print("Age:", age)
# Float
pi = 3.14
print("Pi:", pi)
# String
name = "Alice"
print("Name:", name)
# Boolean
is_student = True
print("Is Student:", is_student)
# Out:
# Age: 25
# Pi: 3.14
# Name: Alice
# Is Student: True

# %%
"""5. Take two variables, a and b. Assign your first name and last name. Print your Name after adding your First name and Last name together. """

a = "ashish"
b = "latwal"
full_name = a + " " + b
print("Fullname:", full_name)
# Out:
# Fullname: ashish latwal

# %%
"""6.	Declare three variables, consisting of your first name, your last name and Nickname. Write a program that prints out your first name, then your nickname in parenthesis and then your last name"""

first_name = "Ashish"
last_name = "Latwal"
nickname = "Ashu"
print(f"{first_name} ({nickname}) {last_name}")
# Out:
# Ashish (Ashu) Latwal

# %%
"""7.	Declare and assign values to suitable variables and print in the following way:
NAME: NIKUNJ BANSAL   
SAP ID: 500069944 
DATE OF BIRTH: 13 Oct 1999 
ADDRESS: UPES 
                    Bidholi Campus 
                    Pincode: 248007 
Programme: AI & ML                                                                                       
Semester: 2"""

name = "Ashish Latwal"
sap_id = "590027571"
date_of_birth = "01 DEC 2005"
address = "UPES\n\tBidholi Campus\n\tPincode: 248007"
programme = "BCA"
semester = 2
print(f"NAME: {name}\nSAP ID: {sap_id}\nDATE OF BIRTH: {date_of_birth}\nADDRESS: {address}\nProgramme: {programme}\nSemester: {semester}")
# Out:
# NAME: Ashish Latwal
# SAP ID: 590027571
# DATE OF BIRTH: 01 DEC 2005
# ADDRESS: UPES
# 	Bidholi Campus
# 	Pincode: 248007
# Programme: BCA
# Semester: 2
