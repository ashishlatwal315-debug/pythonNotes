# %%
num = int(input("Enter a number: "))
rev = 0


while num > 0:
    digit = num % 10
    rev = rev * 10 + digit
    num = num // 10
    

print("Reversed number:", rev)
pel = rev
if rev == pel:
        print("it is palindrom")
else:
        print("not palindrom")
# Out:
# Reversed number: 323232
# it is palindrom

# %%
a = 5%2
print(a)

b = 10/3
print(b)

c = 10//3
print(c)
# Out:
# 1
# 3.3333333333333335
# 3
